# %% [markdown]
# 1- What is Python, and why is it popular ?
#  Python is a high-level, general-purpose, and open-source programming language that is easy to read, write, and learn.
#
# It is popular because:
#
# It has a simple syntax, making it beginner-friendly.
#
# It offers a large collection of libraries like Pandas, NumPy, Matplotlib, and Scikit-learn that are very useful for data analytics, machine learning, and visualization.
#
# It has a strong community support, so learners and professionals can easily find help and resources.
#
# Python is versatile, used not only in data analytics but also in web development, artificial intelligence, automation, and more.
#
# 2. What is an interpreter in Python?
# The Python interpreter is a program that executes code line by line. It translates human-readable Python code into machine instructions. This makes debugging easier and allows immediate feedback when running Python programs.
#
# 3. What are pre-defined keywords in Python?
# Keywords are special reserved words in Python that have predefined meanings and purposes. They cannot be used as variable names.
# Examples: if, else, while, for, True, False, None, def, class.
#
# 4. Can keywords be used as variable names?
# No. Keywords cannot be used as variable names because they are reserved for special functions in Python.
# Example: Writing if = 5 will give an error.
#
# 5. What is mutability in Python?
# Mutability means the ability of an object to be changed after it is created. If the contents of an object can be modified, it is mutable; if not, it is immutable.
#
# 6. Why are lists mutable, but tuples are immutable?
#
# Lists are mutable because their elements can be changed, added, or removed after creation.
#
# Tuples are immutable because once created, their values cannot be modified. This makes tuples faster and safer for fixed data.
#
# 7. What is the difference between == and is operators in Python?
#
# == checks if the values of two objects are the same.
#
# is checks if two variables refer to the same memory location (object identity).
#
# Example:
#
# a = [1, 2, 3]
# b = [1, 2, 3]
# print(a == b)  # True (same values)
# print(a is b)  # False (different objects in memory)
#
#
# 8. What are logical operators in Python?
# Logical operators are used to combine conditional statements:
#
# and → returns True if both conditions are True.
#
# or → returns True if at least one condition is True.
#
# not → reverses the result (True becomes False, False becomes True).
#
# 9. What is type casting in Python?
# Type casting is the process of converting one data type into another.
# Example:
#
# x = "100"
# y = int(x)  # type casting string to integer
#
#
# 10. What is the difference between implicit and explicit type casting?
#
# Implicit casting (Type Conversion): Done automatically by Python. Example: 3 + 2.5 = 5.5 (integer converted to float).
#
# Explicit casting (Type Casting): Done manually using functions like int(), float(), str().
#
# 11. What is the purpose of conditional statements in Python?
# Conditional statements allow decision-making in code. They let a program execute certain blocks of code only when specific conditions are True.
#
# Example:
#
# if age >= 18:
#     print("Eligible to vote")
# else:
#     print("Not eligible")
#
#
# 12. How does the elif statement work?
# The elif (else if) statement checks multiple conditions one by one. As soon as one condition is True, the corresponding block executes, and the rest are skipped.
#
# Example:
#
# marks = 75
# if marks >= 90:
#     print("Grade A")
# elif marks >= 60:
#     print("Grade B")
# else:
#     print("Grade C")
#
#
# 13. What is the difference between for and while loops?
#
# for loop → used when the number of iterations is known.
#
# while loop → used when the number of iterations is unknown and depends on a condition.
#
# 14. Describe a scenario where a while loop is more suitable than a for loop.
# When we don’t know in advance how many times the loop should run.
# Example: Keep asking the user to enter a password until they enter the correct one.
#
# password = ""
# while password != "1234":
#     password = input("Enter password: ")
# print("Access granted")

# %%
1. Print "Hello, World!"

print("Hello, World!")


2. Display your name and age

name = "Ankesh Mishra"
age = 25
print("My name is", name, "and my age is", age)


3. Print all pre-defined keywords in Python

import keyword
print("Python Keywords are:")
print(keyword.kwlist)


4. Check if a given word is a Python keyword

import keyword

word = input("Enter a word: ")
if keyword.iskeyword(word):
    print(word, "is a Python keyword.")
else:
    print(word, "is NOT a Python keyword.")


5. Function to show mutable vs immutable arguments

def modify_list(mylist):
    mylist.append(100)  # changes original list (mutable)

def modify_number(num):
    num = num + 10      # does not change original number (immutable)
    return num

lst = [1, 2, 3]
num = 50

modify_list(lst)
print("After modifying list:", lst)

new_num = modify_number(num)
print("Original number:", num)
print("After function call (new number):", new_num)


6. Basic arithmetic operations on two user-input numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)


7. Demonstrate logical operators

x = True
y = False

print("x and y:", x and y)
print("x or y:", x or y)
print("not x:", not x)


8. List vs Tuple mutability

my_list = [10, 20, 30]
my_tuple = (10, 20, 30)

my_list[1] = 200   # Works, because lists are mutable
print("Modified list:", my_list)

try:
    my_tuple[1] = 200  # Error, tuples are immutable
except TypeError:
    print("Tuples cannot be changed after creation")


9. Convert user input into int, float, and bool

value = input("Enter something: ")

print("As integer:", int(value))
print("As float:", float(value))
print("As boolean:", bool(value))


10. Type casting with list elements

my_list = ["1", "2", "3", "4"]
int_list = [int(x) for x in my_list]
print("Original list:", my_list)
print("After type casting to integers:", int_list)


11. Check if number is positive, negative, or zero

num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")


12. For loop to print 1 to 10

for i in range(1, 11):
    print(i)


13. Sum of even numbers between 1 and 50

total = 0
for i in range(2, 51, 2):
    total += i
print("Sum of even numbers from 1 to 50:", total)


14. Reverse a string using while loop

s = input("Enter a string: ")
rev = ""
i = len(s) - 1

while i >= 0:
    rev += s[i]
    i -= 1

print("Reversed string:", rev)


15. Factorial of a number using while loop

num = int(input("Enter a number: "))
fact = 1
i = 1

while i <= num:
    fact *= i
    i += 1

print("Factorial of", num, "is:", fact)
